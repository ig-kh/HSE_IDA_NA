# %%
import pandas as pd
import numpy as np
import networkx as nx
import pulp as pl
from itertools import islice

# %%
DIST_CSV = "data/50_nodes/distance_matrix.csv"
OFFICE_CSV = "data/50_nodes/offices.csv"
REQS_CSV = "data/50_nodes/reqs.csv"

C = 90                # vehicle capacity
K_INIT_PATHS = 5      # number of initial paths per request
MAX_CG_ITERS = 200    # maximum number of CG iterations
EPS = 1e-8            # tolerance for reduced cost (seek < -EPS)
TIME_LIMIT_LP = 300   # seconds limit for LP stage (optional)
TIME_LIMIT_MIP = 600  # seconds limit for final MIP

# %%
dist_df = pd.read_csv(DIST_CSV)      # src,dst,price
office_df = pd.read_csv(OFFICE_CSV)  # office_id,transfer_price,transfer_max
reqs_df = pd.read_csv(REQS_CSV)      # src_office_id,dst_office,volume

# build directed graph
G = nx.DiGraph()
for _, row in dist_df.iterrows():
    u, v = row['src'], row['dst']
    G.add_edge(u, v, price=float(row['price']))

# offices data
transfer_price = office_df.set_index('office_id')['transfer_price'].to_dict()
transfer_max = office_df.set_index('office_id')['transfer_max'].to_dict()

# requests list
reqs = []
for idx, r in reqs_df.iterrows():
    reqs.append({
        'id': int(idx),
        's': r['src_office_id'],
        't': r['dst_office_id'],
        'd': float(r['volume'])
    })

# %%
def transit_cost_of_path(path, transfer_price_map):
    # path: list of nodes [v0, v1, ..., vn], exclude endpoints
    return sum(transfer_price_map.get(v, 0.0) for v in path[1:-1])

# helper: shortest simple paths generator limited to k
def k_shortest_simple_paths(G_in, source, target, k=1, weight='weight'):
    # networkx.shortest_simple_paths returns generator sorted by path weight
    try:
        gen = nx.shortest_simple_paths(G_in, source, target, weight=weight)
        return list(islice(gen, k))
    except Exception:
        return []

# %%
paths_for_req = {}  # dict: req_id -> list of paths (each path is list of nodes)
for r in reqs:
    s, t = r['s'], r['t']
    # build H where edge weight = price + transfer_price[dst] unless dst==t
    H = nx.DiGraph()
    for u, v, dat in G.edges(data=True):
        node_transit = transfer_price.get(v, 0.0) if v != t else 0.0
        w = dat['price'] + node_transit
        H.add_edge(u, v, weight=w, price=dat['price'])
    sel = k_shortest_simple_paths(H, s, t, k=K_INIT_PATHS, weight='weight')
    if H.has_edge(s, t):
        sel.append([s, t])
    if len(sel) == 0:
        raise ValueError(f"No path found for request {r['id']} from {s} to {t}")
    paths_for_req[r['id']] = sel

# %%
import pulp as pl

def build_initial_master(G, reqs, paths_for_req, C, transfer_price, transfer_max, TIME_LIMIT_LP=600):
    """
    Creates the initial master LP model for Column Generation using PuLP.
    
    Parameters:
    - G: NetworkX DiGraph with 'price' attribute for edges
    - reqs: list of dicts with keys 'id', 's' (source), 't' (target), 'd' (demand)
    - paths_for_req: dict {rid: [ [path1], [path2], ... ]}
    - C: capacity of one vehicle
    - transfer_price: dict {v: transfer cost at node v}
    - transfer_max: dict {v: max incoming capacity at node v}
    - TIME_LIMIT_LP: timeout for LP (seconds)
    
    Returns:
    - prob: PuLP model
    - x_vars: dict of flow variables {(rid, pid): {'var': var, 'path': path}}
    - y_vars: dict of vehicle variables {(u,v): var}
    - demand_constr, edgecap_constr, node_in_constr: dicts of constraints
    """

    prob = pl.LpProblem("master_lp", pl.LpMinimize)

    # Set solver with time limit
    solver = pl.PULP_CBC_CMD(msg=0, timeLimit=TIME_LIMIT_LP, warmStart=True)
    prob.setSolver(solver)

    # Create y variables for edges (vehicle usage)
    y_vars = {}
    for u, v in G.edges():
        y = pl.LpVariable(f"y_{u}_{v}", lowBound=0, cat='Continuous')
        y_vars[(u, v)] = y

    # Create x variables and collect expressions for constraints
    x_vars = {}
    demand_constr = {}     # rid -> LpConstraint
    edgecap_constr = {}    # (u,v) -> LpConstraint
    node_in_constr = {}    # v -> LpConstraint

    for r in reqs:
        rid = r['id']
        s_r = r['s']
        t_r = r['t']
        d_r = r['d']

        # Initialize demand expression
        demand_expr = pl.LpAffineExpression()

        for pid, path in enumerate(paths_for_req[rid]):
            # Transit cost: sum transfer_price for transit nodes (excluding source and target)
            transit_cost = sum(transfer_price.get(v, 0.0) for v in path[1:-1])
            x = pl.LpVariable(f"x_{rid}_{pid}", lowBound=0, cat='Continuous')
            x_vars[(rid, pid)] = {'var': x, 'path': path}

            # Demand expression
            demand_expr += x

            # Edge capacity expressions
            for e in zip(path[:-1], path[1:]):
                if e not in edgecap_constr:
                    edgecap_constr[e] = pl.LpAffineExpression()
                edgecap_constr[e] += x

            # Node incoming expressions (excluding source and target)
            for v in path[1:]:
                if v != s_r and v != t_r:
                    if v not in node_in_constr:
                        node_in_constr[v] = pl.LpAffineExpression()
                    node_in_constr[v] += x

        # Add demand constraint
        demand_constr[rid] = prob.addConstraint(demand_expr == d_r, name=f"demand_{rid}")

    # Add edge capacity constraints
    for (u, v), expr in edgecap_constr.items():
        edgecap_constr[(u, v)] = prob.addConstraint(expr <= C * y_vars[(u, v)], name=f"edgecap_{u}_{v}")

    # Add node incoming constraints
    for v, expr in node_in_constr.items():
        cap = transfer_max.get(v, float('inf'))
        node_in_constr[v] = prob.addConstraint(expr <= cap, name=f"node_in_{v}")

    # Set objective: sum of edge prices * y_vars + transit costs * x_vars
    obj = pl.LpAffineExpression()
    for (u, v), y in y_vars.items():
        obj += G[u][v]['price'] * y
    for (rid, pid), rec in x_vars.items():
        x = rec['var']
        transit_cost = sum(transfer_price.get(v, 0.0) for v in rec['path'][1:-1])
        obj += transit_cost * x
    prob.setObjective(obj)

    return prob, x_vars, y_vars, demand_constr, edgecap_constr, node_in_constr

# %%
master, x_vars, y_vars, demand_constr, edgecap_constr, node_in_constr = build_initial_master(
    G, reqs, paths_for_req, C, transfer_price, transfer_max
)
print("Initial master LP built. Initial columns per request:", {k: len(v) for k, v in paths_for_req.items()})
# Out:
    status = pl.LpStatus[model.status]
    if status != 'Optimal':
        # If infeasible, try to diagnose
        if status == 'Infeasible':
            print("Model is infeasible. Writing LP file for debugging.")
            model.write('master_lp.lp')
        raise RuntimeError(f"Master LP solve failed or not optimal. Status: {status}")

    # Extract duals
    pi = {}     # demand duals
    beta = {}   # edgecap duals
    gamma = {}  # node_in duals

    for k in demand_constr:
        constr = model.constraints[f"demand_{k}"]
        pi[k] = constr.pi if constr.pi is not None else 0.0
    for e in edgecap_constr:
        constr = model.constraints[f"edgecap_{e[0]}_{e[1]}"]
        beta[e] = constr.pi if constr.pi is not None else 0.0
    for v in node_in_constr:
        constr = model.constraints[f"node_in_{v}"]
        gamma[v] = constr.pi if constr.pi is not None else 0.0

    obj_val = pl.value(model.objective) if model.objective is not None else float('inf')
    return pi, beta, gamma, obj_val

def pricing_for_request(rk, pi, beta, gamma):
    s, t = rk['s'], rk['t']
    H = nx.DiGraph()
    for u, v in G.edges():
        be = beta.get((u, v), 0.0)
        node_cost = 0.0
        if v != t:
            node_cost = transfer_price.get(v, 0.0) + gamma.get(v, 0.0)
        w = be + node_cost
        H.add_edge(u, v, weight=w)
    try:
        p = nx.shortest_path(H, s, t, weight='weight')
    except Exception:
        return None, None
    path_edges = list(zip(p[:-1], p[1:]))
    sum_beta = sum(beta.get(e, 0.0) for e in path_edges)
    sum_gamma = sum(gamma.get(v, 0.0) for v in p[1:-1])
    path_transit = sum(transfer_price.get(v, 0.0) for v in p[1:-1])
    pi_k = pi[rk['id']]
    return p, (path_transit + sum_beta + sum_gamma - pi_k)

# %%
iter_count = 0
while True:
    iter_count += 1
    print(f"\n=== CG iteration {iter_count} ===")

    # Solve master LP and extract duals
    pi, beta, gamma, lp_obj = extract_duals(master, demand_constr, edgecap_constr, node_in_constr)
    print(f"Master LP objective: {lp_obj:.6f}")

    # Pricing: for each request, find best path and its reduced cost
    new_columns = 0
    for r in reqs:
        rid = r['id']
        p, path_cost_sum = pricing_for_request(r, pi, beta, gamma)
        if p is None:
            continue

        redcost = path_cost_sum - pi[rid]
        print(f"req {rid}: best path {p} reduced cost = {redcost:.6e}")

        if redcost < -EPS:
            # Build new x variable
            x = pl.LpVariable(f"x_{rid}_cg{iter_count}", lowBound=0, cat='Continuous')
            x_vars[(rid, f"cg{iter_count}")] = {'var': x, 'path': p}

            # Update demand constraint
            demand_expr = pl.LpAffineExpression()
            for (rid2, pid), rec in x_vars.items():
                if rid2 == rid:
                    demand_expr += rec['var']
            master.constraints[f"demand_{rid}"] = demand_expr == r['d']

            # Update edge capacity constraints
            for e in zip(p[:-1], p[1:]):
                if e not in edgecap_constr:
                    edgecap_constr[e] = pl.LpAffineExpression()
                    edgecap_constr[e] = master.addConstraint(edgecap_constr[e] <= C * y_vars[e], name=f"edgecap_{e[0]}_{e[1]}")
                edgecap_expr = pl.LpAffineExpression()
                for (rid2, pid), rec in x_vars.items():
                    path = rec['path']
                    if e in list(zip(path[:-1], path[1:])):
                        edgecap_expr += rec['var']
                master.constraints[f"edgecap_{e[0]}_{e[1]}"] = edgecap_expr <= C * y_vars[e]

            # Update node incoming constraints
            for v in p[1:]:
                if v != r['s'] and v != r['t']:
                    if v not in node_in_constr:
                        node_in_constr[v] = pl.LpAffineExpression()
                        cap = transfer_max.get(v, float('inf'))
                        node_in_constr[v] = master.addConstraint(node_in_constr[v] <= cap, name=f"node_in_{v}")
                    node_in_expr = pl.LpAffineExpression()
                    for (rid2, pid), rec in x_vars.items():
                        path = rec['path']
                        if v in path[1:-1]:
                            node_in_expr += rec['var']
                    master.constraints[f"node_in_{v}"] = node_in_expr <= transfer_max.get(v, float('inf'))

            # Update objective
            obj = pl.LpAffineExpression()
            for (u, v), y in y_vars.items():
                obj += G[u][v]['price'] * y
            for (rid, pid), rec in x_vars.items():
                x_var = rec['var']
                transit_cost = sum(transfer_price.get(v, 0.0) for v in rec['path'][1:-1])
                obj += transit_cost * x_var
            master.setObjective(obj)

            new_columns += 1
            print(f"  -> Added column for req {rid}, path {p}")

    if new_columns == 0:
        print("No columns with negative reduced cost found. Stopping CG.")
        break
    if iter_count >= MAX_CG_ITERS:
        print("Reached max CG iterations. Stopping.")
        break

# Final LP solve

solution_ll = []

master.solve()
print("Final master LP objective:", pl.value(master.objective))

# Solve MILP: make y variables integer
print("\nSolving final MILP on generated columns (make y integer)...")
for e, yv in y_vars.items():
    yv.cat = 'Integer'
solver = pl.PULP_CBC_CMD(msg=1, timeLimit=TIME_LIMIT_MIP, warmStart=True)
master.setSolver(solver)
master.solve()

if pl.LpStatus[master.status] in ['Optimal', 'Not Solved']:
    print("MIP finished with status", pl.LpStatus[master.status])
    mip_obj = pl.value(master.objective)
    print("MIP objective:", mip_obj)
    sol_y = {e: int(round(pl.value(y_vars[e]))) for e in y_vars if pl.value(y_vars[e]) is not None and pl.value(y_vars[e]) > 1e-9}
    sol_x = {}
    for (rid, pid), rec in x_vars.items():
        var = rec['var']
        val = pl.value(var) if pl.value(var) is not None else 0.0
        if val > 1e-8:
            sol_x[(rid, pid)] = {'flow': val, 'path': rec['path']}
    print("\nSelected y (edge -> vehicles):")
    for e, cnt in sol_y.items():
        print(f"  {e}: {cnt}")
    print("\nSelected flows x (req,path,flow):")
    for (rid, pid), rec in sol_x.items():
        print(f"  req {rid} path {rec['path']} flow {rec['flow']:.3f}")
        solution_ll.append([
            int(rec['path'][0]),
            int(rec['path'][-1]),
            float(rec['flow']),
            [int(v) for v in rec['path']],
        ])
else:
    raise RuntimeError(f"MIP didn't return feasible/optimal solution; status: {pl.LpStatus[master.status]}")
# Out:
# === CG iteration 1 ===
# Master LP objective: 338056322020.992371
# req 68: best path [np.int64(16142), np.float64(10303.0), np.int64(16366)] reduced cost = -3.377408e+07
#   -> Added column for req 68, path [np.int64(16142), np.float64(10303.0), np.int64(16366)]
# req 118: best path [np.int64(10270), np.float64(10303.0), np.int64(15028)] reduced cost = -3.411159e+07
#   -> Added column for req 118, path [np.int64(10270), np.float64(10303.0), np.int64(15028)]
# req 723: best path [np.int64(10570), np.float64(10303.0), np.int64(15028)] reduced cost = -3.560862e+07
#   -> Added column for req 723, path [np.int64(10570), np.float64(10303.0), np.int64(15028)]
# req 1784: best path [np.int64(13250), np.float64(15973.0)] reduced cost = -1.154822e+07
#   -> Added column for req 1784, path [np.int64(13250), np.float64(15973.0)]
#
# === CG iteration 2 ===
# Master LP objective: 338056322020.992371
# req 68: best path [np.int64(16142), np.float64(10303.0), np.int64(16366)] reduced cost = -4.435040e+07
#   -> Added column for req 68, path [np.int64(16142), np.float64(10303.0), np.int64(16366)]
#
# === CG iteration 3 ===
# Master LP objective: 338056322020.992371
# req 68: best path [np.int64(16142), np.float64(16366.0)] reduced cost = -3.189681e+07
#   -> Added column for req 68, path [np.int64(16142), np.float64(16366.0)]
#
# === CG iteration 4 ===
# Master LP objective: 338056322020.992371
# No columns with negative reduced cost found. Stopping CG.
# Final master LP objective: 338056322020.9924
#
# Solving final MILP on generated columns (make y integer)...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/igkh/codes/photo2sketch/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/f3529d2842fd4af7b340c56158d2009a-pulp.mps -mips /tmp/f3529d2842fd4af7b340c56158d2009a-pulp.mst -sec 600 -timeMode elapsed -branch -printingOptions all -solution /tmp/f3529d2842fd4af7b340c56158d2009a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 5162 COLUMNS
# At line 121876 RHS
# At line 127034 BOUNDS
# At line 136737 ENDATA
# Problem MODEL has 5157 rows, 22344 columns and 77558 elements
# Coin0008I MODEL read with 0 errors
# opening mipstart file /tmp/f3529d2842fd4af7b340c56158d2009a-pulp.mst.
# MIPStart values read for 22344 variables.
# seconds was changed from 1e+100 to 600
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3.38056e+11 - 0.08 seconds
# Cgl0003I 0 fixed, 2958 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 5151 rows, 15114 columns (2958 integer (0 of which binary)) and 76569 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0012I Integer solution of 5.2584085e+11 found by DiveCoefficient after 0 iterations and 0 nodes (0.37 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 1523 rows 3149 columns
# Cbc0012I Integer solution of 4.1456397e+11 found by DiveCoefficient after 18343 iterations and 0 nodes (14.09 seconds)
# Cbc0031I 3089 added rows had average density of 11.255422
# Cbc0013I At root node, 3089 cuts changed objective from 3.3805632e+11 to 4.0580533e+11 in 50 passes
# Cbc0014I Cut generator 0 (Probing) - 1013 row cuts average 2.5 elements, 1 column cuts (2025 active)  in 0.129 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 3427 row cuts average 18.3 elements, 0 column cuts (0 active)  in 5.944 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.108 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 6269 row cuts average 7.2 elements, 0 column cuts (0 active)  in 0.249 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.292 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 7575 row cuts average 14.7 elements, 0 column cuts (0 active)  in 1.607 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 4.1456397e+11 best solution, best possible 4.0580533e+11 (14.66 seconds)
# Cbc0012I Integer solution of 4.1435852e+11 found by rounding after 18360 iterations and 1 nodes (15.32 seconds)
# Cbc0012I Integer solution of 4.1420943e+11 found by rounding after 18884 iterations and 2 nodes (20.15 seconds)
# Cbc0012I Integer solution of 4.1417259e+11 found by rounding after 20608 iterations and 8 nodes (36.29 seconds)
# Cbc0012I Integer solution of 4.139766e+11 found by rounding after 20875 iterations and 9 nodes (39.19 seconds)
# Cbc0012I Integer solution of 4.1395811e+11 found by rounding after 20967 iterations and 10 nodes (39.85 seconds)
# Cbc0012I Integer solution of 4.1376416e+11 found by rounding after 21983 iterations and 13 nodes (47.21 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2462 rows 7376 columns
# Cbc0012I Integer solution of 4.1366434e+11 found by rounding after 31175 iterations and 54 nodes (71.72 seconds)
# Cbc0012I Integer solution of 4.1353019e+11 found by rounding after 31241 iterations and 55 nodes (72.50 seconds)
# Cbc0012I Integer solution of 4.1352565e+11 found by rounding after 31280 iterations and 56 nodes (73.19 seconds)
# Cbc0012I Integer solution of 4.1339179e+11 found by rounding after 31747 iterations and 57 nodes (74.17 seconds)
# Cbc0012I Integer solution of 4.1335619e+11 found by rounding after 31857 iterations and 58 nodes (74.91 seconds)
# Cbc0012I Integer solution of 4.1317552e+11 found by rounding after 32462 iterations and 60 nodes (76.07 seconds)
# Cbc0012I Integer solution of 4.1311162e+11 found by rounding after 33954 iterations and 70 nodes (79.23 seconds)
# Cbc0012I Integer solution of 4.1291191e+11 found by rounding after 35243 iterations and 76 nodes (81.36 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2364 rows 6888 columns
# Cbc0010I After 100 nodes, 60 on tree, 4.1291191e+11 best solution, best possible 4.0580533e+11 (87.44 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2408 rows 7026 columns
# Cbc0010I After 200 nodes, 110 on tree, 4.1291191e+11 best solution, best possible 4.0580533e+11 (104.61 seconds)
# Cbc0012I Integer solution of 4.1272828e+11 found by rounding after 69660 iterations and 282 nodes (123.66 seconds)
# Cbc0012I Integer solution of 4.1263927e+11 found by rounding after 71325 iterations and 286 nodes (126.07 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2404 rows 7044 columns
# Cbc0010I After 300 nodes, 162 on tree, 4.1263927e+11 best solution, best possible 4.0580533e+11 (131.56 seconds)
# Cbc0012I Integer solution of 4.1258827e+11 found by rounding after 83104 iterations and 361 nodes (144.04 seconds)
# Cbc0012I Integer solution of 4.1250482e+11 found by rounding after 84818 iterations and 366 nodes (146.10 seconds)
# Cbc0012I Integer solution of 4.1244137e+11 found by rounding after 86149 iterations and 368 nodes (147.82 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2297 rows 6572 columns
# Cbc0010I After 400 nodes, 210 on tree, 4.1244137e+11 best solution, best possible 4.0580533e+11 (156.15 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2243 rows 6320 columns
# Cbc0010I After 500 nodes, 262 on tree, 4.1244137e+11 best solution, best possible 4.0580533e+11 (177.80 seconds)
# Cbc0010I After 1900 nodes, 1010 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (420.67 seconds)
# Cbc0010I After 2000 nodes, 1057 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (435.94 seconds)
# Cbc0010I After 2100 nodes, 1101 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (452.81 seconds)
# Cbc0010I After 2200 nodes, 1148 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (466.82 seconds)
# Cbc0010I After 2300 nodes, 1196 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (486.88 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 2119 rows 5712 columns
# Cbc0010I After 2400 nodes, 1244 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (502.87 seconds)
# Cbc0010I After 2500 nodes, 1293 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (518.72 seconds)
# Cbc0010I After 2600 nodes, 1342 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (531.87 seconds)
# Cbc0010I After 2700 nodes, 1390 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (545.38 seconds)
# Cbc0010I After 2800 nodes, 1438 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (559.57 seconds)
# Cbc0010I After 2900 nodes, 1484 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (571.87 seconds)
# Cbc0038I Full problem 5151 rows 15114 columns, reduced to 1994 rows 5296 columns
# Cbc0010I After 3000 nodes, 1533 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (587.76 seconds)
# Cbc0010I After 3100 nodes, 1583 on tree, 4.1143633e+11 best solution, best possible 4.0580533e+11 (599.91 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 4.1143633e+11 (best possible 4.0580533e+11), took 443504 iterations and 3101 nodes (600.07 seconds)
# Cbc0032I Strong branching done 14944 times (374286 iterations), fathomed 0 nodes and fixed 187 variables
# Cbc0035I Maximum depth 230, 19 variables fixed on reduced cost
# Cuts at root node changed objective from 3.38056e+11 to 4.05805e+11
# Probing was tried 50 times and created 1014 cuts of which 2024 were active after adding rounds of cuts (0.129 seconds)
# Gomory was tried 3797 times and created 13991 cuts of which 0 were active after adding rounds of cuts (72.722 seconds)
# Knapsack was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.108 seconds)
# Clique was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 3797 times and created 85372 cuts of which 0 were active after adding rounds of cuts (17.137 seconds)
# FlowCover was tried 50 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.292 seconds)
# TwoMirCuts was tried 3797 times and created 42460 cuts of which 0 were active after adding rounds of cuts (45.095 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                411436332242.16369629
# Lower bound:                    405805326456.936
# Gap:                            0.01
# Enumerated nodes:               3101
# Total iterations:               443504
# Time (CPU seconds):             594.14
# Time (Wallclock seconds):       604.92
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):
#   req 1952 path [np.int64(12985), np.int64(12214)] flow 300.000
#   req 1953 path [np.int64(18863), np.float64(16991.0)] flow 48.000
#   req 1954 path [np.int64(15872), np.int64(14076)] flow 1.000
#   req 1955 path [np.int64(15973), np.int64(13503)] flow 300.000
#   req 1956 path [np.int64(12627), np.float64(15506.0), np.int64(16991)] flow 8.000
#   req 1956 path [np.int64(12627), np.float64(15506.0), np.float64(18863.0), np.int64(16991)] flow 22.000
#   req 1956 path [np.int64(12627), np.int64(16991)] flow 270.000
#   req 1957 path [np.int64(16053), np.int64(19469)] flow 76.000
#   req 1958 path [np.int64(13503), np.float64(14005.0), np.float64(12985.0), np.float64(13179.0), np.int64(17495)] flow 1.000
#   req 1959 path [np.int64(16366), np.float64(16133.0), np.float64(14724.0), np.int64(15872)] flow 30.000
#   req 1959 path [np.int64(16366), np.int64(15872)] flow 270.000
#   req 1960 path [np.int64(14005), np.float64(12627.0), np.int64(15506)] flow 1.000
#   req 1961 path [np.int64(14005), np.int64(17535)] flow 236.000
#   req 1962 path [np.int64(16219), np.int64(13250)] flow 300.000
#   req 1963 path [np.int64(10708), np.float64(14252.0), np.int64(16262)] flow 30.000
#   req 1963 path [np.int64(10708), np.int64(16262)] flow 270.000
#   req 1964 path [np.int64(19311), np.float64(14070.0), np.float64(13474.0), np.int64(13856)] flow 1.000
#   req 1965 path [np.int64(10303), np.int64(19338)] flow 34.000
#   req 1966 path [np.int64(19311), np.int64(13578)] flow 231.000
#   req 1967 path [np.int64(14252), np.int64(10270)] flow 300.000
#   req 1968 path [np.int64(15872), np.float64(14076.0), np.float64(13523.0), np.int64(18849)] flow 30.000
#   req 1968 path [np.int64(15872), np.int64(18849)] flow 270.000
#   req 1969 path [np.int64(12214), np.int64(10270)] flow 300.000
#   req 1970 path [np.int64(11168), np.float64(16053.0)] flow 225.000
#   req 1971 path [np.int64(10303), np.float64(15973.0), np.float64(19469.0), np.float64(10989.0), np.float64(11117.0)] flow 1.000
#   req 1972 path [np.int64(19371), np.float64(13578.0), np.int64(13856)] flow 30.000
#   req 1972 path [np.int64(19371), np.int64(13856)] flow 270.000
#   req 1973 path [np.int64(10044), np.int64(12985)] flow 112.000
#   req 1974 path [np.int64(10303), np.float64(15973.0), np.int64(18446)] flow 1.000
#   req 1974 path [np.int64(10303), np.float64(12985.0), np.int64(18446)] flow 4.000
#   req 1974 path [np.int64(10303), np.int64(18446)] flow 180.000
#   req 1975 path [np.int64(14252), np.float64(18476.0), np.int64(15872)] flow 1.000
#   req 1976 path [np.int64(18182), np.float64(18476.0), np.int64(16219)] flow 23.000
#   req 1976 path [np.int64(18182), np.int64(16219)] flow 270.000
#   req 1977 path [np.int64(14724), np.float64(12627.0), np.float64(12985.0), np.int64(13179)] flow 1.000
#   req 1978 path [np.int64(18863), np.float64(16991.0), np.float64(13474.0), np.int64(13183)] flow 1.000
#   req 1979 path [np.int64(16991), np.int64(17770)] flow 250.000
#   req 1980 path [np.int64(10570), np.float64(19185.0), np.float64(10708.0)] flow 1.000
#   req 1981 path [np.int64(17784), np.float64(10904.0), np.int64(16262)] flow 1.000
#   req 1982 path [np.int64(10303), np.int64(18849)] flow 300.000
#   req 1983 path [np.int64(15206), np.float64(13179.0), np.float64(10044.0), np.int64(12985)] flow 1.000
#   req 1984 path [np.int64(15872), np.float64(12627.0), np.float64(12985.0), np.int64(10904)] flow 1.000
#   req 1985 path [np.int64(15872), np.float64(14076.0), np.float64(19542.0), np.float64(13474.0), np.float64(10989.0), np.float64(17253.0), np.int64(15204)] flow 1.000
#   req 1986 path [np.int64(16219), np.int64(14724)] flow 300.000
#   req 1987 path [np.int64(17784), np.float64(10904.0), np.int64(13431)] flow 1.000
#   req 1988 path [np.int64(19371), np.float64(13578.0)] flow 300.000
#   req 1989 path [np.int64(14005), np.float64(14076.0), np.float64(19542.0), np.float64(13523.0), np.int64(10327)] flow 1.000
#   req 1990 path [np.int64(15401), np.float64(11861.0), np.float64(16133.0), np.int64(13250)] flow 1.000
#   req 1991 path [np.int64(12214), np.int64(15872)] flow 300.000
#   req 1992 path [np.int64(14724), np.int64(19539)] flow 300.000
#   req 1993 path [np.int64(17784), np.float64(10904.0), np.float64(13474.0), np.float64(10989.0), np.float64(17253.0), np.int64(17770)] flow 1.000
#   req 1994 path [np.int64(15872), np.int64(14724)] flow 1.000
#   req 1995 path [np.int64(18182), np.int64(11168)] flow 15.000
#   req 1996 path [np.int64(13183), np.float64(16262.0), np.int64(15401)] flow 1.000
#   req 1997 path [np.int64(19921), np.int64(17535)] flow 47.000
#   req 1998 path [np.int64(15506), np.int64(15973)] flow 300.000
#   req 1999 path [np.int64(19371), np.float64(15401.0), np.int64(11861)] flow 1.000
#   req 2000 path [np.int64(10708), np.int64(18182)] flow 300.000
#   req 2001 path [np.int64(10570), np.int64(10327)] flow 146.000
#   req 2002 path [np.int64(17547), np.int64(19921)] flow 1.000
#   req 2003 path [np.int64(12985), np.int64(11861)] flow 300.000
#   req 2004 path [np.int64(18863), np.int64(15747)] flow 248.000
#   req 2005 path [np.int64(11461), np.int64(13250)] flow 243.000
#   req 2006 path [np.int64(17547), np.float64(15506.0), np.int64(18863)] flow 1.000
#   req 2007 path [np.int64(13183), np.float64(16262.0), np.int64(10270)] flow 29.000
#   req 2007 path [np.int64(13183), np.int64(10270)] flow 180.000
#   req 2008 path [np.int64(14005), np.int64(16991)] flow 121.000
#   req 2009 path [np.int64(17547), np.int64(15506)] flow 1.000
#   req 2010 path [np.int64(19921), np.int64(12985)] flow 76.000
#   req 2011 path [np.int64(15973), np.int64(19539)] flow 300.000
#   req 2012 path [np.int64(17039), np.float64(18577.0), np.int64(16262)] flow 179.000
#   req 2012 path [np.int64(17039), np.float64(11861.0), np.float64(13183.0), np.int64(16262)] flow 121.000
#   req 2013 path [np.int64(18144), np.int64(18182)] flow 66.000
#   req 2014 path [np.int64(12627), np.float64(10044.0), np.float64(16219.0), np.float64(10178.0), np.int64(11568)] flow 1.000
#   req 2015 path [np.int64(13503), np.float64(12627.0), np.float64(19542.0), np.float64(13523.0), np.int64(11214)] flow 1.000
#   req 2016 path [np.int64(18863), np.float64(16991.0), np.float64(13474.0), np.float64(10989.0), np.float64(17253.0), np.int64(14376)] flow 1.000
#   req 2017 path [np.int64(10570), np.int64(18144)] flow 113.000
#   req 2018 path [np.int64(12627), np.float64(14076.0), np.float64(13523.0), np.int64(18849)] flow 10.000
#   req 2018 path [np.int64(12627), np.int64(18849)] flow 270.000
#   req 2019 path [np.int64(15747), np.float64(11267.0), np.float64(13179.0), np.int64(19311)] flow 1.000
#   req 2020 path [np.int64(19311), np.float64(14070.0)] flow 121.000
#   req 2021 path [np.int64(17770), np.float64(17253.0), np.float64(13856.0), np.float64(16133.0), np.int64(15973)] flow 1.000
#   req 2022 path [np.int64(16219), np.int64(16262)] flow 124.000
#   req 2023 path [np.int64(10708), np.float64(17784.0), np.int64(19542)] flow 1.000
#   req 2024 path [np.int64(17784), np.float64(12663.0), np.int64(14252)] flow 30.000
#   req 2024 path [np.int64(17784), np.int64(14252)] flow 270.000
#   req 2025 path [np.int64(10708), np.float64(14252.0), np.int64(13474)] flow 30.000
#   req 2025 path [np.int64(10708), np.int64(13474)] flow 270.000
#   req 2026 path [np.int64(19311), np.int64(17784)] flow 131.000
#   req 2027 path [np.int64(13503), np.float64(14724.0), np.int64(14444)] flow 1.000
#   req 2028 path [np.int64(10044), np.int64(12214)] flow 120.000
#   req 2029 path [np.int64(13503), np.int64(16916)] flow 203.000
#   req 2030 path [np.int64(15872), np.float64(10044.0), np.float64(12985.0), np.float64(13179.0), np.int64(14070)] flow 2.000
#   req 2030 path [np.int64(15872), np.int64(14070)] flow 270.000
#   req 2031 path [np.int64(11461), np.float64(14005.0)] flow 213.000
#   req 2032 path [np.int64(11461), np.int64(12952)] flow 180.000
#   req 2033 path [np.int64(16053), np.float64(18182.0), np.float64(18476.0), np.int64(15916)] flow 1.000
#   req 2034 path [np.int64(16991), np.float64(13179.0), np.int64(18476)] flow 1.000
#   req 2035 path [np.int64(10270), np.float64(17547.0), np.float64(19469.0), np.float64(13474.0), np.float64(10989.0), np.float64(17253.0), np.float64(15204.0), np.int64(15262)] flow 1.000
#   req 2036 path [np.int64(14005), np.int64(13570)] flow 300.000
#   req 2037 path [np.int64(15401), np.float64(10376.0)] flow 105.000
#   req 2038 path [np.int64(12627), np.float64(12985.0), np.float64(13179.0), np.int64(18476)] flow 1.000
#   req 2039 path [np.int64(16991), np.int64(13856)] flow 300.000
#   req 2040 path [np.int64(10270), np.int64(17822)] flow 300.000
#   req 2041 path [np.int64(14724), np.float64(15872.0), np.int64(14076)] flow 1.000
#   req 2042 path [np.int64(10270), np.float64(17547.0), np.float64(19469.0), np.float64(13474.0), np.int64(18978)] flow 1.000
#   req 2043 path [np.int64(11461), np.float64(17784.0)] flow 72.000
#   req 2044 path [np.int64(15872), np.int64(17312)] flow 300.000
#   req 2045 path [np.int64(19956), np.int64(14376)] flow 161.000
#   req 2046 path [np.int64(16262), np.float64(18476.0), np.int64(13503)] flow 1.000
#   req 2047 path [np.int64(10570), np.int64(18863)] flow 300.000
#   req 2048 path [np.int64(15872), np.float64(16219.0), np.float64(10178.0), np.int64(13570)] flow 1.000
#   req 2049 path [np.int64(12627), np.float64(15506.0), np.int64(18863)] flow 1.000
#   req 2050 path [np.int64(17784), np.int64(13474)] flow 300.000
#   req 2051 path [np.int64(14724), np.float64(19469.0), np.float64(10989.0), np.float64(17253.0), np.float64(15204.0), np.int64(15028)] flow 1.000
#   req 2052 path [np.int64(11267), np.int64(11168)] flow 300.000
#   req 2053 path [np.int64(13680), np.float64(15262.0), np.float64(15204.0), np.float64(17253.0), np.float64(13856.0), np.float64(16133.0), np.float64(14724.0), np.int64(15872)] flow 30.000
#   req 2053 path [np.int64(13680), np.int64(15872)] flow 270.000
#   req 2054 path [np.int64(18144), np.float64(12573.0), np.int64(16262)] flow 210.000
#   req 2054 path [np.int64(18144), np.int64(16262)] flow 90.000
#   req 2055 path [np.int64(10708), np.float64(14252.0)] flow 300.000
#   req 2056 path [np.int64(18863), np.float64(16991.0), np.float64(13474.0), np.int64(19338)] flow 1.000
#   req 2057 path [np.int64(11267), np.float64(10904.0), np.float64(13474.0), np.float64(10989.0), np.float64(15028.0)] flow 1.000
#   req 2058 path [np.int64(12627), np.float64(19542.0), np.float64(13474.0), np.int64(19338)] flow 1.000
#   req 2059 path [np.int64(10044), np.float64(19542.0)] flow 1.000
#   req 2060 path [np.int64(11267), np.float64(13179.0), np.float64(19171.0)] flow 1.000
#   req 2061 path [np.int64(10708), np.float64(14252.0), np.float64(13474.0), np.int64(12280)] flow 1.000
#   req 2062 path [np.int64(10570), np.float64(13651.0), np.float64(10708.0), np.float64(15916.0), np.int64(12214)] flow 30.000
#   req 2062 path [np.int64(10570), np.float64(12214.0)] flow 270.000
#   req 2063 path [np.int64(18863), np.int64(14444)] flow 300.000
#   req 2064 path [np.int64(15401), np.float64(19371.0), np.float64(13578.0), np.float64(10989.0), np.float64(11117.0)] flow 1.000
#   req 2065 path [np.int64(18863), np.float64(16991.0), np.float64(12985.0), np.int64(12663)] flow 1.000
#   req 2066 path [np.int64(18144), np.float64(14444.0), np.int64(19180)] flow 30.000
#   req 2066 path [np.int64(18144), np.int64(19180)] flow 270.000
#   req 2067 path [np.int64(15872), np.float64(10044.0)] flow 1.000
#   req 2068 path [np.int64(15973), np.float64(19469.0), np.float64(15401.0)] flow 1.000
#   req 2069 path [np.int64(12627), np.float64(12985.0), np.int64(12663)] flow 1.000
#   req 2070 path [np.int64(16219), np.float64(19469.0), np.float64(13474.0), np.int64(19338)] flow 1.000
#   req 2071 path [np.int64(12985), np.float64(15506.0), np.int64(18863)] flow 1.000
#   req 2072 path [np.int64(13503), np.float64(14005.0), np.float64(12985.0), np.int64(12663)] flow 23.000
#   req 2073 path [np.int64(17784), np.float64(10904.0), np.float64(13474.0), np.int64(13578)] flow 1.000
#   req 2074 path [np.int64(18863), np.int64(13856)] flow 152.000
#   req 2075 path [np.int64(19371), np.float64(15401.0), np.int64(13101)] flow 1.000
#   req 2076 path [np.int64(11267), np.int64(16219)] flow 300.000
#   req 2077 path [np.int64(18978), np.float64(19956.0), np.float64(15204.0), np.int64(15028)] flow 24.000
#   req 2077 path [np.int64(18978), np.int64(15028)] flow 180.000
#   req 2078 path [np.int64(19921), np.int64(13250)] flow 300.000
#   req 2079 path [np.int64(19921), np.float64(16219.0), np.int64(10178)] flow 30.000
#   req 2079 path [np.int64(19921), np.int64(10178)] flow 270.000
#   req 2080 path [np.int64(11461), np.float64(14076.0), np.int64(19542)] flow 1.000
#   req 2081 path [np.int64(16219), np.float64(10178.0), np.int64(13570)] flow 30.000
#   req 2081 path [np.int64(16219), np.int64(13570)] flow 270.000
#   req 2082 path [np.int64(13680), np.float64(15262.0), np.float64(15204.0), np.float64(17253.0), np.float64(13856.0), np.float64(16133.0), np.float64(13179.0), np.float64(19539.0), np.int64(11267)] flow 1.000
#   req 2083 path [np.int64(15401), np.int64(19371)] flow 1.000
#   req 2084 path [np.int64(10708), np.float64(17312.0), np.int64(13431)] flow 34.000
#   req 2085 path [np.int64(14005), np.int64(15206)] flow 300.000
#   req 2086 path [np.int64(11461), np.float64(10044.0), np.float64(12985.0), np.float64(13179.0), np.int64(10708)] flow 1.000
#   req 2087 path [np.int64(15973), np.int64(14376)] flow 300.000
#   req 2088 path [np.int64(13503), np.int64(13474)] flow 60.000
#   req 2089 path [np.int64(10270), np.int64(19338)] flow 136.000
#   req 2090 path [np.int64(13503), np.float64(14005.0), np.float64(12985.0), np.float64(13179.0), np.int64(17312)] flow 1.000
#   req 2091 path [np.int64(11461), np.int64(11472)] flow 293.000
#   req 2092 path [np.int64(18978), np.int64(13250)] flow 259.000
#   req 2093 path [np.int64(13503), np.int64(13250)] flow 56.000
#   req 2094 path [np.int64(12627), np.int64(19956)] flow 300.000
#   req 2095 path [np.int64(18978), np.float64(19956.0), np.float64(15204.0), np.int64(11117)] flow 1.000
#   req 2096 path [np.int64(17784), np.float64(13179.0), np.float64(19171.0)] flow 1.000
#   req 2097 path [np.int64(12985), np.float64(13179.0), np.int64(17495)] flow 1.000
#   req 2098 path [np.int64(16262), np.float64(10989.0), np.int64(17039)] flow 26.000
#   req 2098 path [np.int64(16262), np.int64(17039)] flow 90.000
#   req 2099 path [np.int64(14005), np.int64(13250)] flow 56.000
#   req 2100 path [np.int64(17784), np.int64(18978)] flow 237.000
#   req 2101 path [np.int64(17784), np.float64(13179.0), np.int64(19539)] flow 1.000
#   req 2102 path [np.int64(16219), np.int64(10904)] flow 300.000
#   req 2103 path [np.int64(15973), np.float64(19469.0), np.float64(19539.0), np.int64(15747)] flow 1.000
#   req 2104 path [np.int64(10044), np.float64(15872.0), np.int64(18144)] flow 1.000
#   req 2105 path [np.int64(13856), np.float64(16133.0), np.float64(14724.0), np.int64(15872)] flow 1.000

# %%
pd.DataFrame(solution_ll).to_csv("/home/igkh/codes/HSE_IDA_NA/solutions/50_nodes.csv", index=False)
