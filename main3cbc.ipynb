# %%
import pandas as pd
import numpy as np
import networkx as nx
import pulp as pl
from itertools import islice

# %%
DIST_CSV = "data/20_nodes/distance_matrix.csv"
OFFICE_CSV = "data/20_nodes/offices.csv"
REQS_CSV = "data/20_nodes/reqs.csv"

C = 90                # vehicle capacity
K_INIT_PATHS = 5      # number of initial paths per request
MAX_CG_ITERS = 200    # maximum number of CG iterations
EPS = 1e-8            # tolerance for reduced cost (seek < -EPS)
TIME_LIMIT_LP = 300   # seconds limit for LP stage (optional)
TIME_LIMIT_MIP = 600  # seconds limit for final MIP

# %%
dist_df = pd.read_csv(DIST_CSV)      # src,dst,price
office_df = pd.read_csv(OFFICE_CSV)  # office_id,transfer_price,transfer_max
reqs_df = pd.read_csv(REQS_CSV)      # src_office_id,dst_office,volume

# build directed graph
G = nx.DiGraph()
for _, row in dist_df.iterrows():
    u, v = row['src'], row['dst']
    G.add_edge(u, v, price=float(row['price']))

# offices data
transfer_price = office_df.set_index('office_id')['transfer_price'].to_dict()
transfer_max = office_df.set_index('office_id')['transfer_max'].to_dict()

# requests list
reqs = []
for idx, r in reqs_df.iterrows():
    reqs.append({
        'id': int(idx),
        's': r['src_office_id'],
        't': r['dst_office_id'],
        'd': float(r['volume'])
    })

# %%
def transit_cost_of_path(path, transfer_price_map):
    # path: list of nodes [v0, v1, ..., vn], exclude endpoints
    return sum(transfer_price_map.get(v, 0.0) for v in path[1:-1])

# helper: shortest simple paths generator limited to k
def k_shortest_simple_paths(G_in, source, target, k=1, weight='weight'):
    # networkx.shortest_simple_paths returns generator sorted by path weight
    try:
        gen = nx.shortest_simple_paths(G_in, source, target, weight=weight)
        return list(islice(gen, k))
    except Exception:
        return []

# %%
paths_for_req = {}  # dict: req_id -> list of paths (each path is list of nodes)
for r in reqs:
    s, t = r['s'], r['t']
    # build H where edge weight = price + transfer_price[dst] unless dst==t
    H = nx.DiGraph()
    for u, v, dat in G.edges(data=True):
        node_transit = transfer_price.get(v, 0.0) if v != t else 0.0
        w = dat['price'] + node_transit
        H.add_edge(u, v, weight=w, price=dat['price'])
    sel = k_shortest_simple_paths(H, s, t, k=K_INIT_PATHS, weight='weight')
    if H.has_edge(s, t):
        sel.append([s, t])
    if len(sel) == 0:
        raise ValueError(f"No path found for request {r['id']} from {s} to {t}")
    paths_for_req[r['id']] = sel

# %%
import pulp as pl

def build_initial_master(G, reqs, paths_for_req, C, transfer_price, transfer_max, TIME_LIMIT_LP=600):
    """
    Creates the initial master LP model for Column Generation using PuLP.
    
    Parameters:
    - G: NetworkX DiGraph with 'price' attribute for edges
    - reqs: list of dicts with keys 'id', 's' (source), 't' (target), 'd' (demand)
    - paths_for_req: dict {rid: [ [path1], [path2], ... ]}
    - C: capacity of one vehicle
    - transfer_price: dict {v: transfer cost at node v}
    - transfer_max: dict {v: max incoming capacity at node v}
    - TIME_LIMIT_LP: timeout for LP (seconds)
    
    Returns:
    - prob: PuLP model
    - x_vars: dict of flow variables {(rid, pid): {'var': var, 'path': path}}
    - y_vars: dict of vehicle variables {(u,v): var}
    - demand_constr, edgecap_constr, node_in_constr: dicts of constraints
    """

    prob = pl.LpProblem("master_lp", pl.LpMinimize)

    # Set solver with time limit
    solver = pl.PULP_CBC_CMD(msg=0, timeLimit=TIME_LIMIT_LP, warmStart=True)
    prob.setSolver(solver)

    # Create y variables for edges (vehicle usage)
    y_vars = {}
    for u, v in G.edges():
        y = pl.LpVariable(f"y_{u}_{v}", lowBound=0, cat='Continuous')
        y_vars[(u, v)] = y

    # Create x variables and collect expressions for constraints
    x_vars = {}
    demand_constr = {}     # rid -> LpConstraint
    edgecap_constr = {}    # (u,v) -> LpConstraint
    node_in_constr = {}    # v -> LpConstraint

    for r in reqs:
        rid = r['id']
        s_r = r['s']
        t_r = r['t']
        d_r = r['d']

        # Initialize demand expression
        demand_expr = pl.LpAffineExpression()

        for pid, path in enumerate(paths_for_req[rid]):
            # Transit cost: sum transfer_price for transit nodes (excluding source and target)
            transit_cost = sum(transfer_price.get(v, 0.0) for v in path[1:-1])
            x = pl.LpVariable(f"x_{rid}_{pid}", lowBound=0, cat='Continuous')
            x_vars[(rid, pid)] = {'var': x, 'path': path}

            # Demand expression
            demand_expr += x

            # Edge capacity expressions
            for e in zip(path[:-1], path[1:]):
                if e not in edgecap_constr:
                    edgecap_constr[e] = pl.LpAffineExpression()
                edgecap_constr[e] += x

            # Node incoming expressions (excluding source and target)
            for v in path[1:]:
                if v != s_r and v != t_r:
                    if v not in node_in_constr:
                        node_in_constr[v] = pl.LpAffineExpression()
                    node_in_constr[v] += x

        # Add demand constraint
        demand_constr[rid] = prob.addConstraint(demand_expr == d_r, name=f"demand_{rid}")

    # Add edge capacity constraints
    for (u, v), expr in edgecap_constr.items():
        edgecap_constr[(u, v)] = prob.addConstraint(expr <= C * y_vars[(u, v)], name=f"edgecap_{u}_{v}")

    # Add node incoming constraints
    for v, expr in node_in_constr.items():
        cap = transfer_max.get(v, float('inf'))
        node_in_constr[v] = prob.addConstraint(expr <= cap, name=f"node_in_{v}")

    # Set objective: sum of edge prices * y_vars + transit costs * x_vars
    obj = pl.LpAffineExpression()
    for (u, v), y in y_vars.items():
        obj += G[u][v]['price'] * y
    for (rid, pid), rec in x_vars.items():
        x = rec['var']
        transit_cost = sum(transfer_price.get(v, 0.0) for v in rec['path'][1:-1])
        obj += transit_cost * x
    prob.setObjective(obj)

    return prob, x_vars, y_vars, demand_constr, edgecap_constr, node_in_constr

# %%
master, x_vars, y_vars, demand_constr, edgecap_constr, node_in_constr = build_initial_master(
    G, reqs, paths_for_req, C, transfer_price, transfer_max
)
print("Initial master LP built. Initial columns per request:", {k: len(v) for k, v in paths_for_req.items()})
# Out:
# Initial master LP built. Initial columns per request: {0: 6, 1: 6, 2: 6, 3: 6, 4: 6, 5: 6, 6: 6, 7: 6, 8: 6, 9: 6, 10: 6, 11: 6, 12: 6, 13: 6, 14: 6, 15: 6, 16: 6, 17: 6, 18: 6, 19: 6, 20: 6, 21: 6, 22: 6, 23: 6, 24: 6, 25: 6, 26: 6, 27: 6, 28: 6, 29: 6, 30: 6, 31: 6, 32: 6, 33: 6, 34: 6, 35: 6, 36: 6, 37: 6, 38: 6, 39: 6, 40: 6, 41: 6, 42: 6, 43: 6, 44: 6, 45: 6, 46: 6, 47: 6, 48: 6, 49: 6, 50: 6, 51: 6, 52: 6, 53: 6, 54: 6, 55: 6, 56: 6, 57: 6, 58: 6, 59: 6, 60: 6, 61: 6, 62: 6, 63: 6, 64: 6, 65: 6, 66: 6, 67: 6, 68: 6, 69: 6, 70: 6, 71: 6, 72: 6, 73: 6, 74: 6, 75: 6, 76: 6, 77: 6, 78: 6, 79: 6, 80: 6, 81: 6, 82: 6, 83: 6, 84: 6, 85: 6, 86: 6, 87: 6, 88: 6, 89: 6, 90: 6, 91: 6, 92: 6, 93: 6, 94: 6, 95: 6, 96: 6, 97: 6, 98: 6, 99: 6, 100: 6, 101: 6, 102: 6, 103: 6, 104: 6, 105: 6, 106: 6, 107: 6, 108: 6, 109: 6, 110: 6, 111: 6, 112: 6, 113: 6, 114: 6}

# %%
def extract_duals(model, demand_constr, edgecap_constr, node_in_constr):
    # Solve the model with duals enabled
    solver = pl.PULP_CBC_CMD(msg=0, timeLimit=TIME_LIMIT_LP, warmStart=True, keepFiles=True)
    model.setSolver(solver)
    model.solve()

    # Check solver status
    status = pl.LpStatus[model.status]
    if status != 'Optimal':
        # If infeasible, try to diagnose
        if status == 'Infeasible':
            print("Model is infeasible. Writing LP file for debugging.")
            model.write('master_lp.lp')
        raise RuntimeError(f"Master LP solve failed or not optimal. Status: {status}")

    # Extract duals
    pi = {}     # demand duals
    beta = {}   # edgecap duals
    gamma = {}  # node_in duals

    for k in demand_constr:
        constr = model.constraints[f"demand_{k}"]
        pi[k] = constr.pi if constr.pi is not None else 0.0
    for e in edgecap_constr:
        constr = model.constraints[f"edgecap_{e[0]}_{e[1]}"]
        beta[e] = constr.pi if constr.pi is not None else 0.0
    for v in node_in_constr:
        constr = model.constraints[f"node_in_{v}"]
        gamma[v] = constr.pi if constr.pi is not None else 0.0

    obj_val = pl.value(model.objective) if model.objective is not None else float('inf')
    return pi, beta, gamma, obj_val

def pricing_for_request(rk, pi, beta, gamma):
    s, t = rk['s'], rk['t']
    H = nx.DiGraph()
    for u, v in G.edges():
        be = beta.get((u, v), 0.0)
        node_cost = 0.0
        if v != t:
            node_cost = transfer_price.get(v, 0.0) + gamma.get(v, 0.0)
        w = be + node_cost
        H.add_edge(u, v, weight=w)
    try:
        p = nx.shortest_path(H, s, t, weight='weight')
    except Exception:
        return None, None
    path_edges = list(zip(p[:-1], p[1:]))
    sum_beta = sum(beta.get(e, 0.0) for e in path_edges)
    sum_gamma = sum(gamma.get(v, 0.0) for v in p[1:-1])
    path_transit = sum(transfer_price.get(v, 0.0) for v in p[1:-1])
    pi_k = pi[rk['id']]
    return p, (path_transit + sum_beta + sum_gamma - pi_k)

# %%
iter_count = 0
while True:
    iter_count += 1
    print(f"\n=== CG iteration {iter_count} ===")

    # Solve master LP and extract duals
    pi, beta, gamma, lp_obj = extract_duals(master, demand_constr, edgecap_constr, node_in_constr)
    print(f"Master LP objective: {lp_obj:.6f}")

    # Pricing: for each request, find best path and its reduced cost
    new_columns = 0
    for r in reqs:
        rid = r['id']
        p, path_cost_sum = pricing_for_request(r, pi, beta, gamma)
        if p is None:
            continue

        redcost = path_cost_sum - pi[rid]
        print(f"req {rid}: best path {p} reduced cost = {redcost:.6e}")

        if redcost < -EPS:
            # Build new x variable
            x = pl.LpVariable(f"x_{rid}_cg{iter_count}", lowBound=0, cat='Continuous')
            x_vars[(rid, f"cg{iter_count}")] = {'var': x, 'path': p}

            # Update demand constraint
            demand_expr = pl.LpAffineExpression()
            for (rid2, pid), rec in x_vars.items():
                if rid2 == rid:
                    demand_expr += rec['var']
            master.constraints[f"demand_{rid}"] = demand_expr == r['d']

            # Update edge capacity constraints
            for e in zip(p[:-1], p[1:]):
                if e not in edgecap_constr:
                    edgecap_constr[e] = pl.LpAffineExpression()
                    edgecap_constr[e] = master.addConstraint(edgecap_constr[e] <= C * y_vars[e], name=f"edgecap_{e[0]}_{e[1]}")
                edgecap_expr = pl.LpAffineExpression()
                for (rid2, pid), rec in x_vars.items():
                    path = rec['path']
                    if e in list(zip(path[:-1], path[1:])):
                        edgecap_expr += rec['var']
                master.constraints[f"edgecap_{e[0]}_{e[1]}"] = edgecap_expr <= C * y_vars[e]

            # Update node incoming constraints
            for v in p[1:]:
                if v != r['s'] and v != r['t']:
                    if v not in node_in_constr:
                        node_in_constr[v] = pl.LpAffineExpression()
                        cap = transfer_max.get(v, float('inf'))
                        node_in_constr[v] = master.addConstraint(node_in_constr[v] <= cap, name=f"node_in_{v}")
                    node_in_expr = pl.LpAffineExpression()
                    for (rid2, pid), rec in x_vars.items():
                        path = rec['path']
                        if v in path[1:-1]:
                            node_in_expr += rec['var']
                    master.constraints[f"node_in_{v}"] = node_in_expr <= transfer_max.get(v, float('inf'))

            # Update objective
            obj = pl.LpAffineExpression()
            for (u, v), y in y_vars.items():
                obj += G[u][v]['price'] * y
            for (rid, pid), rec in x_vars.items():
                x_var = rec['var']
                transit_cost = sum(transfer_price.get(v, 0.0) for v in rec['path'][1:-1])
                obj += transit_cost * x_var
            master.setObjective(obj)

            new_columns += 1
            print(f"  -> Added column for req {rid}, path {p}")

    if new_columns == 0:
        print("No columns with negative reduced cost found. Stopping CG.")
        break
    if iter_count >= MAX_CG_ITERS:
        print("Reached max CG iterations. Stopping.")
        break

# Final LP solve

solution_ll = []

master.solve()
print("Final master LP objective:", pl.value(master.objective))

# Solve MILP: make y variables integer
print("\nSolving final MILP on generated columns (make y integer)...")
for e, yv in y_vars.items():
    yv.cat = 'Integer'
solver = pl.PULP_CBC_CMD(msg=1, timeLimit=TIME_LIMIT_MIP, warmStart=True)
master.setSolver(solver)
master.solve()

if pl.LpStatus[master.status] in ['Optimal', 'Not Solved']:
    print("MIP finished with status", pl.LpStatus[master.status])
    mip_obj = pl.value(master.objective)
    print("MIP objective:", mip_obj)
    sol_y = {e: int(round(pl.value(y_vars[e]))) for e in y_vars if pl.value(y_vars[e]) is not None and pl.value(y_vars[e]) > 1e-9}
    sol_x = {}
    for (rid, pid), rec in x_vars.items():
        var = rec['var']
        val = pl.value(var) if pl.value(var) is not None else 0.0
        if val > 1e-8:
            sol_x[(rid, pid)] = {'flow': val, 'path': rec['path']}
    print("\nSelected y (edge -> vehicles):")
    for e, cnt in sol_y.items():
        print(f"  {e}: {cnt}")
    print("\nSelected flows x (req,path,flow):")
    for (rid, pid), rec in sol_x.items():
        print(f"  req {rid} path {rec['path']} flow {rec['flow']:.3f}")
        solution_ll.append([
            int(rec['path'][0]),
            int(rec['path'][-1]),
            float(rec['flow']),
            [int(v) for v in rec['path']],
        ])
else:
    raise RuntimeError(f"MIP didn't return feasible/optimal solution; status: {pl.LpStatus[master.status]}")
# Out:
# === CG iteration 1 ===
# Master LP objective: 27433350321.878368
# req 40: best path [np.int64(16313), np.float64(11581.0)] reduced cost = -7.879636e+07
#   -> Added column for req 40, path [np.int64(16313), np.float64(11581.0)]
#
# === CG iteration 2 ===
# Master LP objective: 27433350321.878368
# No columns with negative reduced cost found. Stopping CG.
# Final master LP objective: 27433350321.87837
#
# Solving final MILP on generated columns (make y integer)...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/igkh/codes/photo2sketch/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/b3f087bcd06b4e99ab5c9c975a290b40-pulp.mps -mips /tmp/b3f087bcd06b4e99ab5c9c975a290b40-pulp.mst -sec 600 -timeMode elapsed -branch -printingOptions all -solution /tmp/b3f087bcd06b4e99ab5c9c975a290b40-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 332 COLUMNS
# At line 5615 RHS
# At line 5943 BOUNDS
# At line 6286 ENDATA
# Problem MODEL has 327 rows, 1033 columns and 3729 elements
# Coin0008I MODEL read with 0 errors
# opening mipstart file /tmp/b3f087bcd06b4e99ab5c9c975a290b40-pulp.mst.
# MIPStart values read for 1033 variables.
# seconds was changed from 1e+100 to 600
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 2.74334e+10 - 0.00 seconds
# Cgl0003I 0 fixed, 193 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 326 rows, 836 columns (193 integer (0 of which binary)) and 3628 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0012I Integer solution of 4.3024812e+10 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 137 rows 273 columns
# Cbc0012I Integer solution of 3.5937753e+10 found by DiveCoefficient after 1452 iterations and 0 nodes (0.23 seconds)
# Cbc0031I 213 added rows had average density of 16.906103
# Cbc0013I At root node, 213 cuts changed objective from 2.7433351e+10 to 3.1076718e+10 in 35 passes
# Cbc0014I Cut generator 0 (Probing) - 71 row cuts average 4.6 elements, 2 column cuts (113 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 249 row cuts average 28.4 elements, 0 column cuts (0 active)  in 0.070 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 471 row cuts average 5.8 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 554 row cuts average 25.5 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 3.5937753e+10 best solution, best possible 3.1076718e+10 (0.38 seconds)
# Cbc0012I Integer solution of 3.3566222e+10 found by rounding after 1571 iterations and 1 nodes (0.39 seconds)
# Cbc0012I Integer solution of 3.351916e+10 found by DiveCoefficient after 1571 iterations and 1 nodes (0.39 seconds)
# Cbc0012I Integer solution of 3.2546981e+10 found by DiveCoefficient after 1907 iterations and 1 nodes (0.47 seconds)
# Cbc0012I Integer solution of 3.250107e+10 found by DiveCoefficient after 1910 iterations and 2 nodes (0.49 seconds)
# Cbc0012I Integer solution of 3.2398676e+10 found by DiveCoefficient after 1930 iterations and 2 nodes (0.54 seconds)
# Cbc0012I Integer solution of 3.2043317e+10 found by DiveCoefficient after 2059 iterations and 5 nodes (0.79 seconds)
# Cbc0012I Integer solution of 3.1978199e+10 found by DiveCoefficient after 2063 iterations and 5 nodes (0.85 seconds)
# Cbc0012I Integer solution of 3.1928003e+10 found by DiveCoefficient after 2640 iterations and 18 nodes (1.03 seconds)
# Cbc0012I Integer solution of 3.1923502e+10 found by DiveCoefficient after 2835 iterations and 24 nodes (1.11 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 134 rows 299 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 129 rows 288 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 137 rows 314 columns
# Cbc0012I Integer solution of 3.1881331e+10 found by rounding after 10290 iterations and 237 nodes (2.08 seconds)
# Cbc0012I Integer solution of 3.1872745e+10 found by rounding after 10458 iterations and 247 nodes (2.10 seconds)
# Cbc0012I Integer solution of 3.1834788e+10 found by rounding after 10479 iterations and 249 nodes (2.11 seconds)
# Cbc0012I Integer solution of 3.1798583e+10 found by rounding after 11021 iterations and 272 nodes (2.17 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 107 rows 218 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 114 rows 251 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 117 rows 253 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 152 rows 341 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 139 rows 315 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 138 rows 309 columns
# Cbc0010I After 1000 nodes, 415 on tree, 3.1798583e+10 best solution, best possible 3.1076718e+10 (4.69 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 150 rows 333 columns
# Cbc0012I Integer solution of 3.179712e+10 found by rounding after 41486 iterations and 1517 nodes (5.79 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 146 rows 317 columns
# Cbc0010I After 2000 nodes, 654 on tree, 3.179712e+10 best solution, best possible 3.1076718e+10 (7.09 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 159 rows 353 columns
# Cbc0038I Full problem 326 rows 836 columns, reduced to 156 rows 343 columns
# Cbc0010I After 3000 nodes, 1077 on tree, 3.179712e+10 best solution, best possible 3.1076718e+10 (9.90 seconds)
# Cbc0012I Integer solution of 3.1747662e+10 found by rounding after 106767 iterations and 3577 nodes (11.61 seconds)
# Cbc0012I Integer solution of 3.1745549e+10 found by rounding after 106902 iterations and 3587 nodes (11.63 seconds)
# Cbc0012I Integer solution of 3.1737922e+10 found by rounding after 106911 iterations and 3588 nodes (11.63 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 103 rows 210 columns
# Cbc0010I After 4000 nodes, 1294 on tree, 3.1737922e+10 best solution, best possible 3.1076718e+10 (12.77 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 124 rows 269 columns
# Cbc0012I Integer solution of 3.172953e+10 found by rounding after 137336 iterations and 4729 nodes (14.68 seconds)
# Cbc0012I Integer solution of 3.1729318e+10 found by rounding after 137396 iterations and 4731 nodes (14.68 seconds)
# Cbc0012I Integer solution of 3.1683553e+10 found by rounding after 137862 iterations and 4747 nodes (14.71 seconds)
# Cbc0012I Integer solution of 3.1679099e+10 found by rounding after 137974 iterations and 4753 nodes (14.72 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to
seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 154 rows 363 columns
# Cbc0010I After 36000 nodes, 9931 on tree, 3.1647489e+10 best solution, best possible 3.152298e+10 (131.02 seconds)
# Cbc0010I After 37000 nodes, 10308 on tree, 3.1647489e+10 best solution, best possible 3.1524966e+10 (137.74 seconds)
# Cbc0010I After 38000 nodes, 10286 on tree, 3.1647489e+10 best solution, best possible 3.1524966e+10 (139.80 seconds)
# Cbc0010I After 39000 nodes, 10502 on tree, 3.1647489e+10 best solution, best possible 3.1524973e+10 (142.16 seconds)
# Cbc0010I After 40000 nodes, 10720 on tree, 3.1647489e+10 best solution, best possible 3.1524973e+10 (144.79 seconds)
# Cbc0010I After 41000 nodes, 10592 on tree, 3.1647489e+10 best solution, best possible 3.1524973e+10 (146.26 seconds)
# Cbc0004I Integer solution of 3.164689e+10 found after 1447544 iterations and 41842 nodes (147.94 seconds)
# Cbc0010I After 42000 nodes, 10612 on tree, 3.164689e+10 best solution, best possible 3.1524973e+10 (148.30 seconds)
# Cbc0012I Integer solution of 3.1645006e+10 found by rounding after 1458391 iterations and 42269 nodes (148.94 seconds)
# Cbc0004I Integer solution of 3.1643447e+10 found after 1460128 iterations and 42334 nodes (149.03 seconds)
# Cbc0004I Integer solution of 3.1643231e+10 found after 1460344 iterations and 42344 nodes (149.05 seconds)
# Cbc0010I After 43000 nodes, 10607 on tree, 3.1643231e+10 best solution, best possible 3.1524973e+10 (150.32 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 140 rows 315 columns
# Cbc0010I After 44000 nodes, 10820 on tree, 3.1643231e+10 best solution, best possible 3.1524973e+10 (152.96 seconds)
# Cbc0012I Integer solution of 3.1643191e+10 found by rounding after 1519639 iterations and 44806 nodes (154.17 seconds)
# Cbc0010I After 45000 nodes, 10709 on tree, 3.1643191e+10 best solution, best possible 3.1524973e+10 (154.56 seconds)
# Cbc0010I After 46000 nodes, 10681 on tree, 3.1643191e+10 best solution, best possible 3.1524977e+10 (156.60 seconds)
# Cbc0012I Integer solution of 3.1641437e+10 found by rounding after 1585937 iterations and 46894 nodes (158.88 seconds)
# Cbc0012I Integer solution of 3.1641208e+10 found by rounding after 1586115 iterations and 46903 nodes (158.90 seconds)
# Cbc0012I Integer solution of 3.1640993e+10 found by rounding after 1586229 iterations and 46906 nodes (158.90 seconds)
# Cbc0010I After 47000 nodes, 10782 on tree, 3.1640993e+10 best solution, best possible 3.1524977e+10 (159.09 seconds)
# Cbc0012I Integer solution of 3.1635626e+10 found by rounding after 1589804 iterations and 47028 nodes (159.15 seconds)
# Cbc0012I Integer solution of 3.1635397e+10 found by rounding after 1590044 iterations and 47041 nodes (159.18 seconds)
# Cbc0012I Integer solution of 3.1635182e+10 found by rounding after 1590151 iterations and 47044 nodes (159.18 seconds)
# Cbc0010I After 48000 nodes, 10676 on tree, 3.1635182e+10 best solution, best possible 3.1524977e+10 (161.21 seconds)
# Cbc0010I After 49000 nodes, 10543 on tree, 3.1635182e+10 best solution, best possible 3.1524977e+10 (162.86 seconds)
# Cbc0010I After 50000 nodes, 10474 on tree, 3.1635182e+10 best solution, best possible 3.1524977e+10 (165.13 seconds)
# Cbc0038I Full problem 326 rows 836 columns, reduced to 145 rows 335 columns
# Cbc0010I After 51000 nodes, 10664 on tree, 3.1635182e+10 best s

# %%
pd.DataFrame(solution_ll).to_csv("/home/igkh/codes/HSE_IDA_NA/solutions/20_nodes.csv", index=False)
