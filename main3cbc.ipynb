# %%
import pandas as pd
import numpy as np
import networkx as nx
import pulp as pl
from itertools import islice

# %%
DIST_CSV = "data/10_nodes/distance_matrix.csv"
OFFICE_CSV = "data/10_nodes/offices.csv"
REQS_CSV = "data/10_nodes/reqs.csv"

C = 90                # vehicle capacity
K_INIT_PATHS = 5      # number of initial paths per request
MAX_CG_ITERS = 200    # maximum number of CG iterations
EPS = 1e-8            # tolerance for reduced cost (seek < -EPS)
TIME_LIMIT_LP = 300   # seconds limit for LP stage (optional)
TIME_LIMIT_MIP = 600  # seconds limit for final MIP

# %%
dist_df = pd.read_csv(DIST_CSV)      # src,dst,price
office_df = pd.read_csv(OFFICE_CSV)  # office_id,transfer_price,transfer_max
reqs_df = pd.read_csv(REQS_CSV)      # src_office_id,dst_office,volume

# build directed graph
G = nx.DiGraph()
for _, row in dist_df.iterrows():
    u, v = row['src'], row['dst']
    G.add_edge(u, v, price=float(row['price']))

# offices data
transfer_price = office_df.set_index('office_id')['transfer_price'].to_dict()
transfer_max = office_df.set_index('office_id')['transfer_max'].to_dict()

# requests list
reqs = []
for idx, r in reqs_df.iterrows():
    reqs.append({
        'id': int(idx),
        's': r['src_office_id'],
        't': r['dst_office_id'],
        'd': float(r['volume'])
    })

# %%
def transit_cost_of_path(path, transfer_price_map):
    # path: list of nodes [v0, v1, ..., vn], exclude endpoints
    return sum(transfer_price_map.get(v, 0.0) for v in path[1:-1])

# helper: shortest simple paths generator limited to k
def k_shortest_simple_paths(G_in, source, target, k=1, weight='weight'):
    # networkx.shortest_simple_paths returns generator sorted by path weight
    try:
        gen = nx.shortest_simple_paths(G_in, source, target, weight=weight)
        return list(islice(gen, k))
    except Exception:
        return []

# %%
paths_for_req = {}  # dict: req_id -> list of paths (each path is list of nodes)
for r in reqs:
    s, t = r['s'], r['t']
    # build H where edge weight = price + transfer_price[dst] unless dst==t
    H = nx.DiGraph()
    for u, v, dat in G.edges(data=True):
        node_transit = transfer_price.get(v, 0.0) if v != t else 0.0
        w = dat['price'] + node_transit
        H.add_edge(u, v, weight=w, price=dat['price'])
    sel = k_shortest_simple_paths(H, s, t, k=K_INIT_PATHS, weight='weight')
    if H.has_edge(s, t):
        sel.append([s, t])
    if len(sel) == 0:
        raise ValueError(f"No path found for request {r['id']} from {s} to {t}")
    paths_for_req[r['id']] = sel
# Out:
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added
# added

# %%
import pulp as pl

def build_initial_master(G, reqs, paths_for_req, C, transfer_price, transfer_max, TIME_LIMIT_LP=600):
    """
    Creates the initial master LP model for Column Generation using PuLP.
    
    Parameters:
    - G: NetworkX DiGraph with 'price' attribute for edges
    - reqs: list of dicts with keys 'id', 's' (source), 't' (target), 'd' (demand)
    - paths_for_req: dict {rid: [ [path1], [path2], ... ]}
    - C: capacity of one vehicle
    - transfer_price: dict {v: transfer cost at node v}
    - transfer_max: dict {v: max incoming capacity at node v}
    - TIME_LIMIT_LP: timeout for LP (seconds)
    
    Returns:
    - prob: PuLP model
    - x_vars: dict of flow variables {(rid, pid): {'var': var, 'path': path}}
    - y_vars: dict of vehicle variables {(u,v): var}
    - demand_constr, edgecap_constr, node_in_constr: dicts of constraints
    """

    prob = pl.LpProblem("master_lp", pl.LpMinimize)

    # Set solver with time limit
    solver = pl.PULP_CBC_CMD(msg=0, timeLimit=TIME_LIMIT_LP, warmStart=True)
    prob.setSolver(solver)

    # Create y variables for edges (vehicle usage)
    y_vars = {}
    for u, v in G.edges():
        y = pl.LpVariable(f"y_{u}_{v}", lowBound=0, cat='Continuous')
        y_vars[(u, v)] = y

    # Create x variables and collect expressions for constraints
    x_vars = {}
    demand_constr = {}     # rid -> LpConstraint
    edgecap_constr = {}    # (u,v) -> LpConstraint
    node_in_constr = {}    # v -> LpConstraint

    for r in reqs:
        rid = r['id']
        s_r = r['s']
        t_r = r['t']
        d_r = r['d']

        # Initialize demand expression
        demand_expr = pl.LpAffineExpression()

        for pid, path in enumerate(paths_for_req[rid]):
            # Transit cost: sum transfer_price for transit nodes (excluding source and target)
            transit_cost = sum(transfer_price.get(v, 0.0) for v in path[1:-1])
            x = pl.LpVariable(f"x_{rid}_{pid}", lowBound=0, cat='Continuous')
            x_vars[(rid, pid)] = {'var': x, 'path': path}

            # Demand expression
            demand_expr += x

            # Edge capacity expressions
            for e in zip(path[:-1], path[1:]):
                if e not in edgecap_constr:
                    edgecap_constr[e] = pl.LpAffineExpression()
                edgecap_constr[e] += x

            # Node incoming expressions (excluding source and target)
            for v in path[1:]:
                if v != s_r and v != t_r:
                    if v not in node_in_constr:
                        node_in_constr[v] = pl.LpAffineExpression()
                    node_in_constr[v] += x

        # Add demand constraint
        demand_constr[rid] = prob.addConstraint(demand_expr == d_r, name=f"demand_{rid}")

    # Add edge capacity constraints
    for (u, v), expr in edgecap_constr.items():
        edgecap_constr[(u, v)] = prob.addConstraint(expr <= C * y_vars[(u, v)], name=f"edgecap_{u}_{v}")

    # Add node incoming constraints
    for v, expr in node_in_constr.items():
        cap = transfer_max.get(v, float('inf'))
        node_in_constr[v] = prob.addConstraint(expr <= cap, name=f"node_in_{v}")

    # Set objective: sum of edge prices * y_vars + transit costs * x_vars
    obj = pl.LpAffineExpression()
    for (u, v), y in y_vars.items():
        obj += G[u][v]['price'] * y
    for (rid, pid), rec in x_vars.items():
        x = rec['var']
        transit_cost = sum(transfer_price.get(v, 0.0) for v in rec['path'][1:-1])
        obj += transit_cost * x
    prob.setObjective(obj)

    return prob, x_vars, y_vars, demand_constr, edgecap_constr, node_in_constr

# %%
master, x_vars, y_vars, demand_constr, edgecap_constr, node_in_constr = build_initial_master(
    G, reqs, paths_for_req, C, transfer_price, transfer_max
)
print("Initial master LP built. Initial columns per request:", {k: len(v) for k, v in paths_for_req.items()})
# Out:
# Initial master LP built. Initial columns per request: {0: 6, 1: 6, 2: 6, 3: 6, 4: 6, 5: 6, 6: 6, 7: 6, 8: 6, 9: 6, 10: 6, 11: 6, 12: 6, 13: 6, 14: 6, 15: 6, 16: 6, 17: 6, 18: 6, 19: 6, 20: 6, 21: 6, 22: 6, 23: 6, 24: 6, 25: 6}

# %%
def extract_duals(model, demand_constr, edgecap_constr, node_in_constr):
    # Solve the model with duals enabled
    solver = pl.PULP_CBC_CMD(msg=0, timeLimit=TIME_LIMIT_LP, warmStart=True, keepFiles=True)
    model.setSolver(solver)
    model.solve()

    # Check solver status
    status = pl.LpStatus[model.status]
    if status != 'Optimal':
        # If infeasible, try to diagnose
        if status == 'Infeasible':
            print("Model is infeasible. Writing LP file for debugging.")
            model.write('master_lp.lp')
        raise RuntimeError(f"Master LP solve failed or not optimal. Status: {status}")

    # Extract duals
    pi = {}     # demand duals
    beta = {}   # edgecap duals
    gamma = {}  # node_in duals

    for k in demand_constr:
        constr = model.constraints[f"demand_{k}"]
        pi[k] = constr.pi if constr.pi is not None else 0.0
    for e in edgecap_constr:
        constr = model.constraints[f"edgecap_{e[0]}_{e[1]}"]
        beta[e] = constr.pi if constr.pi is not None else 0.0
    for v in node_in_constr:
        constr = model.constraints[f"node_in_{v}"]
        gamma[v] = constr.pi if constr.pi is not None else 0.0

    obj_val = pl.value(model.objective) if model.objective is not None else float('inf')
    return pi, beta, gamma, obj_val

def pricing_for_request(rk, pi, beta, gamma):
    s, t = rk['s'], rk['t']
    H = nx.DiGraph()
    for u, v in G.edges():
        be = beta.get((u, v), 0.0)
        node_cost = 0.0
        if v != t:
            node_cost = transfer_price.get(v, 0.0) + gamma.get(v, 0.0)
        w = be + node_cost
        H.add_edge(u, v, weight=w)
    try:
        p = nx.shortest_path(H, s, t, weight='weight')
    except Exception:
        return None, None
    path_edges = list(zip(p[:-1], p[1:]))
    sum_beta = sum(beta.get(e, 0.0) for e in path_edges)
    sum_gamma = sum(gamma.get(v, 0.0) for v in p[1:-1])
    path_transit = sum(transfer_price.get(v, 0.0) for v in p[1:-1])
    pi_k = pi[rk['id']]
    return p, (path_transit + sum_beta + sum_gamma - pi_k)

# %%
iter_count = 0
while True:
    iter_count += 1
    print(f"\n=== CG iteration {iter_count} ===")

    # Solve master LP and extract duals
    pi, beta, gamma, lp_obj = extract_duals(master, demand_constr, edgecap_constr, node_in_constr)
    print(f"Master LP objective: {lp_obj:.6f}")

    # Pricing: for each request, find best path and its reduced cost
    new_columns = 0
    for r in reqs:
        rid = r['id']
        p, path_cost_sum = pricing_for_request(r, pi, beta, gamma)
        if p is None:
            continue

        redcost = path_cost_sum - pi[rid]
        print(f"req {rid}: best path {p} reduced cost = {redcost:.6e}")

        if redcost < -EPS:
            # Build new x variable
            x = pl.LpVariable(f"x_{rid}_cg{iter_count}", lowBound=0, cat='Continuous')
            x_vars[(rid, f"cg{iter_count}")] = {'var': x, 'path': p}

            # Update demand constraint
            demand_expr = pl.LpAffineExpression()
            for (rid2, pid), rec in x_vars.items():
                if rid2 == rid:
                    demand_expr += rec['var']
            master.constraints[f"demand_{rid}"] = demand_expr == r['d']

            # Update edge capacity constraints
            for e in zip(p[:-1], p[1:]):
                if e not in edgecap_constr:
                    edgecap_constr[e] = pl.LpAffineExpression()
                    edgecap_constr[e] = master.addConstraint(edgecap_constr[e] <= C * y_vars[e], name=f"edgecap_{e[0]}_{e[1]}")
                edgecap_expr = pl.LpAffineExpression()
                for (rid2, pid), rec in x_vars.items():
                    path = rec['path']
                    if e in list(zip(path[:-1], path[1:])):
                        edgecap_expr += rec['var']
                master.constraints[f"edgecap_{e[0]}_{e[1]}"] = edgecap_expr <= C * y_vars[e]

            # Update node incoming constraints
            for v in p[1:]:
                if v != r['s'] and v != r['t']:
                    if v not in node_in_constr:
                        node_in_constr[v] = pl.LpAffineExpression()
                        cap = transfer_max.get(v, float('inf'))
                        node_in_constr[v] = master.addConstraint(node_in_constr[v] <= cap, name=f"node_in_{v}")
                    node_in_expr = pl.LpAffineExpression()
                    for (rid2, pid), rec in x_vars.items():
                        path = rec['path']
                        if v in path[1:-1]:
                            node_in_expr += rec['var']
                    master.constraints[f"node_in_{v}"] = node_in_expr <= transfer_max.get(v, float('inf'))

            # Update objective
            obj = pl.LpAffineExpression()
            for (u, v), y in y_vars.items():
                obj += G[u][v]['price'] * y
            for (rid, pid), rec in x_vars.items():
                x_var = rec['var']
                transit_cost = sum(transfer_price.get(v, 0.0) for v in rec['path'][1:-1])
                obj += transit_cost * x_var
            master.setObjective(obj)

            new_columns += 1
            print(f"  -> Added column for req {rid}, path {p}")

    if new_columns == 0:
        print("No columns with negative reduced cost found. Stopping CG.")
        break
    if iter_count >= MAX_CG_ITERS:
        print("Reached max CG iterations. Stopping.")
        break

# Final LP solve
master.solve()
print("Final master LP objective:", pl.value(master.objective))

# Solve MILP: make y variables integer
print("\nSolving final MILP on generated columns (make y integer)...")
for e, yv in y_vars.items():
    yv.cat = 'Integer'
solver = pl.PULP_CBC_CMD(msg=1, timeLimit=TIME_LIMIT_MIP, warmStart=True)
master.setSolver(solver)
master.solve()

if pl.LpStatus[master.status] in ['Optimal', 'Not Solved']:
    print("MIP finished with status", pl.LpStatus[master.status])
    mip_obj = pl.value(master.objective)
    print("MIP objective:", mip_obj)
    sol_y = {e: int(round(pl.value(y_vars[e]))) for e in y_vars if pl.value(y_vars[e]) is not None and pl.value(y_vars[e]) > 1e-9}
    sol_x = {}
    for (rid, pid), rec in x_vars.items():
        var = rec['var']
        val = pl.value(var) if pl.value(var) is not None else 0.0
        if val > 1e-8:
            sol_x[(rid, pid)] = {'flow': val, 'path': rec['path']}
    print("\nSelected y (edge -> vehicles):")
    for e, cnt in sol_y.items():
        print(f"  {e}: {cnt}")
    print("\nSelected flows x (req,path,flow):")
    for (rid, pid), rec in sol_x.items():
        print(f"  req {rid} path {rec['path']} flow {rec['flow']:.3f}")
else:
    raise RuntimeError(f"MIP didn't return feasible/optimal solution; status: {pl.LpStatus[master.status]}")
# Out:
# === CG iteration 1 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(13505.0), np.int64(16319)] reduced cost = -3.067987e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(13505.0), np.int64(16319)]
# req 10: best path [np.int64(18553), np.float64(16319.0), np.int64(19555)] reduced cost = -7.475585e+06
#   -> Added column for req 10, path [np.int64(18553), np.float64(16319.0), np.int64(19555)]
# req 13: best path [np.int64(16319), np.float64(18553.0), np.int64(19555)] reduced cost = -7.496493e+06
#   -> Added column for req 13, path [np.int64(16319), np.float64(18553.0), np.int64(19555)]
# req 19: best path [np.int64(13505), np.float64(16319.0)] reduced cost = -4.414971e+06
#   -> Added column for req 19, path [np.int64(13505), np.float64(16319.0)]
#
# === CG iteration 2 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 7: best path [np.int64(18553), np.float64(11582.0), np.int64(11178)] reduced cost = -4.000032e+06
#   -> Added column for req 7, path [np.int64(18553), np.float64(11582.0), np.int64(11178)]
# req 25: best path [np.int64(16319), np.float64(13505.0), np.int64(18655)] reduced cost = -4.793967e+06
#   -> Added column for req 25, path [np.int64(16319), np.float64(13505.0), np.int64(18655)]
#
# === CG iteration 3 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 7: best path [np.int64(18553), np.float64(10045.0), np.int64(11178)] reduced cost = -4.000032e+06
#   -> Added column for req 7, path [np.int64(18553), np.float64(10045.0), np.int64(11178)]
# req 25: best path [np.int64(16319), np.float64(18655.0)] reduced cost = -3.951645e+06
#   -> Added column for req 25, path [np.int64(16319), np.float64(18655.0)]
#
# === CG iteration 4 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 7: best path [np.int64(18553), np.float64(10045.0), np.int64(11178)] reduced cost = -4.000032e+06
#   -> Added column for req 7, path [np.int64(18553), np.float64(10045.0), np.int64(11178)]
# req 17: best path [np.int64(16319), np.float64(18553.0), np.int64(11178)] reduced cost = -3.941877e+06
#   -> Added column for req 17, path [np.int64(16319), np.float64(18553.0), np.int64(11178)]
#
# === CG iteration 5 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 17: best path [np.int64(16319), np.float64(10045.0), np.int64(11178)] reduced cost = -3.916509e+06
#   -> Added column for req 17, path [np.int64(16319), np.float64(10045.0), np.int64(11178)]
# req 18: best path [np.int64(18553), np.float64(13505.0), np.int64(18655)] reduced cost = -4.580368e+06
#   -> Added column for req 18, path [np.int64(18553), np.float64(13505.0), np.int64(18655)]
#
# === CG iteration 6 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 17: best path [np.int64(16319), np.float64(11178.0)] reduced cost = -3.837646e+06
#   -> Added column for req 17, path [np.int64(16319), np.float64(11178.0)]
# req 18: best path [np.int64(18553), np.float64(18655.0)] reduced cost = -3.797619e+06
#   -> Added column for req 18, path [np.int64(18553), np.float64(18655.0)]
#
# === CG iteration 7 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 1: best path [np.int64(16319), np.float64(10380.0)] reduced cost = -2.939510e+06
#   -> Added column for req 1, path [np.int64(16319), np.float64(10380.0)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 8 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 21: best path [np.int64(16319), np.float64(11582.0), np.int64(13505)] reduced cost = -3.651030e+06
#   -> Added column for req 21, path [np.int64(16319), np.float64(11582.0), np.int64(13505)]
#
# === CG iteration 9 ===
# Master LP objective: 899616861.269593
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# req 4: best path [np.int64(18553), np.float64(10045.0), np.int64(13505)] reduced cost = -3.705864e+06
#   -> Added column for req 4, path [np.int64(18553), np.float64(10045.0), np.int64(13505)]
# req 21: best path [np.int64(16319), np.float64(18553.0), np.int64(13505)] reduced cost = -3.304320e+06
#   -> Added column for req 21, path [np.int64(16319), np.float64(18553.0), np.int64(13505)]
#
# === CG iteration 10 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(11582.0), np.int64(16319)] reduced cost = -2.469731e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(11582.0), np.int64(16319)]
# req 21: best path [np.int64(16319), np.float64(10045.0), np.int64(13505)] reduced cost = -3.264462e+06
#   -> Added column for req 21, path [np.int64(16319), np.float64(10045.0), np.int64(13505)]
#
# === CG iteration 11 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 12 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 13 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 14 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 15 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 16 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 17 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 18 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 19 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 20 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 21 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 22 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 23 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 24 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 25 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 26 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 27 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 28 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 29 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 30 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 31 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 32 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 33 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 34 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 35 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.934317e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 36 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 37 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 38 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 39 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 40 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 41 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 42 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 43 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 44 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 45 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 46 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 47 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 48 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 49 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 50 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 51 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 52 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 53 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 54 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 55 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 56 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 57 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 58 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 59 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 60 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 61 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 62 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 63 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 64 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 65 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 66 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 67 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 68 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 69 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 70 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 71 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 72 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 73 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 74 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 75 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 76 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 77 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 78 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 79 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 80 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 81 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 82 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 83 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 84 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 85 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 86 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 87 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 88 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 89 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 90 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 91 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 92 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 93 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 94 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 95 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 96 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 97 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 98 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 99 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 100 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 101 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 102 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 103 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 104 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 105 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 106 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 107 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 108 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 109 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 110 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 111 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 112 ===
# Master LP objective: 899616861.269593
# ...
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 184 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 185 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 186 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 187 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 188 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 189 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 190 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 191 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 192 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 193 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 194 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 195 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 196 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 197 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 198 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 199 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
#
# === CG iteration 200 ===
# Master LP objective: 899616861.269593
# req 0: best path [np.int64(18553), np.float64(10045.0), np.int64(10380)] reduced cost = -2.935787e+06
#   -> Added column for req 0, path [np.int64(18553), np.float64(10045.0), np.int64(10380)]
# req 3: best path [np.int64(11178), np.float64(16319.0)] reduced cost = -2.394645e+06
#   -> Added column for req 3, path [np.int64(11178), np.float64(16319.0)]
# Reached max CG iterations. Stopping.
# Final master LP objective: 899616861.2695934
#
# Solving final MILP on generated columns (make y integer)...
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/igkh/codes/photo2sketch/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/linux/i64/cbc /tmp/b9c52213062e4cd69ec7d848df2b050b-pulp.mps -mips /tmp/b9c52213062e4cd69ec7d848df2b050b-pulp.mst -sec 600 -timeMode elapsed -branch -printingOptions all -solution /tmp/b9c52213062e4cd69ec7d848df2b050b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 101 COLUMNS
# At line 2790 RHS
# At line 2887 BOUNDS
# At line 2960 ENDATA
# Problem MODEL has 96 rows, 639 columns and 2148 elements
# Coin0008I MODEL read with 0 errors
# opening mipstart file /tmp/b9c52213062e4cd69ec7d848df2b050b-pulp.mst.
# MIPStart values read for 639 variables.
# seconds was changed from 1e+100 to 600
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8.99617e+08 - 0.00 seconds
# Cgl0003I 0 fixed, 45 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0004I processed model has 96 rows, 206 columns (45 integer (0 of which binary)) and 944 elements
# Cbc0045I Trying just fixing integer variables (and fixingish SOS).
# Cbc0045I Warning: mipstart values could not be used to build a solution.
# Cbc0012I Integer solution of 1.5336751e+09 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 96 rows 206 columns, reduced to 44 rows 85 columns
# Cbc0012I Integer solution of 1.4629244e+09 found by DiveCoefficient after 2959 iterations and 0 nodes (0.24 seconds)
# Cbc0031I 33 added rows had average density of 50.181818
# Cbc0013I At root node, 33 cuts changed objective from 9.0471693e+08 to 1.0696992e+09 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1298 row cuts average 192.3 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 455 row cuts average 4.3 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.021 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 467 row cuts average 21.7 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1.4629244e+09 best solution, best possible 1.0696992e+09 (0.25 seconds)
# Cbc0012I Integer solution of 1.3038343e+09 found by rounding after 2994 iterations and 1 nodes (0.26 seconds)
# Cbc0012I Integer solution of 1.2870142e+09 found by DiveCoefficient after 2994 iterations and 1 nodes (0.26 seconds)
# Cbc0012I Integer solution of 1.1795644e+09 found by DiveCoefficient after 3167 iterations and 1 nodes (0.27 seconds)
# Cbc0012I Integer solution of 1.1429851e+09 found by DiveCoefficient after 3189 iterations and 2 nodes (0.28 seconds)
# Cbc0012I Integer solution of 1.1354121e+09 found by rounding after 3659 iterations and 16 nodes (0.36 seconds)
# Cbc0016I Integer solution of 1.1304272e+09 found by strong branching after 3735 iterations and 21 nodes (0.37 seconds)
# Cbc0012I Integer solution of 1.1227617e+09 found by DiveCoefficient after 4180 iterations and 31 nodes (0.41 seconds)
# Cbc0038I Full problem 96 rows 206 columns, reduced to 51 rows 104 columns
# Cbc0001I Search completed - best objective 1122761691.191, took 6492 iterations and 72 nodes (0.63 seconds)
# Cbc0032I Strong branching done 864 times (13831 iterations), fathomed 19 nodes and fixed 51 variables
# Cbc0035I Maximum depth 12, 85 variables fixed on reduced cost
# Cuts at root node changed objective from 9.04717e+08 to 1.0697e+09
# Probing was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Gomory was tried 277 times and created 1339 cuts of which 0 were active after adding rounds of cuts (0.043 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 277 times and created 999 cuts of which 0 were active after adding rounds of cuts (0.031 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.021 seconds)
# TwoMirCuts was tried 277 times and created 1033 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1122761691.19099998
# Enumerated nodes:               72
# Total iterations:               6492
# Time (CPU seconds):             0.61
# Time (Wallclock seconds):       0.64
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.61   (Wallclock seconds):       0.64
#
# MIP finished with status Optimal
# MIP objective: 1122761691.191
#
# Selected y (edge -> vehicles):
#   (np.float64(18553.0), np.float64(16319.0)): 1
#   (np.float64(18553.0), np.float64(11582.0)): 2
#   (np.float64(16319.0), np.float64(18553.0)): 1
#   (np.float64(16319.0), np.float64(11178.0)): 1
#   (np.float64(16319.0), np.float64(13505.0)): 1
#   (np.float64(16319.0), np.float64(10045.0)): 1
#   (np.float64(16319.0), np.float64(10380.0)): 1
#   (np.float64(11582.0), np.float64(18553.0)): 3
#   (np.float64(11582.0), np.float64(10045.0)): 1
#   (np.float64(11582.0), np.float64(10380.0)): 2
#   (np.float64(11178.0), np.float64(16319.0)): 1
#   (np.float64(18655.0), np.float64(16319.0)): 3
#   (np.float64(13505.0), np.float64(18655.0)): 1
#   (np.float64(10045.0), np.float64(11582.0)): 1
#   (np.float64(10045.0), np.float64(10380.0)): 1
#   (np.float64(10045.0), np.float64(19555.0)): 1
#   (np.float64(10380.0), np.float64(18655.0)): 1
#   (np.float64(10380.0), np.float64(13505.0)): 1
#
# Selected flows x (req,path,flow):
#   req 0 path [np.int64(18553), np.float64(11582.0), np.float64(10380.0)] flow 1.000
#   req 1 path [np.int64(16319), np.float64(18553.0), np.float64(11582.0), np.float64(10380.0)] flow 3.000
#   req 1 path [np.int64(16319), np.float64(10045.0), np.int64(10380)] flow 19.000
#   req 2 path [np.int64(11582), np.int64(18553)] flow 200.000
#   req 4 path [np.int64(18553), np.float64(11582.0), np.float64(10380.0), np.int64(13505)] flow 39.000
#   req 5 path [np.int64(18655), np.int64(16319)] flow 200.000
#   req 6 path [np.int64(11582), np.float64(10045.0), np.int64(19555)] flow 20.000
#   req 7 path [np.int64(18553), np.float64(16319.0), np.float64(11178.0)] flow 2.000
#   req 8 path [np.int64(11582), np.int64(10045)] flow 1.000
#   req 9 path [np.int64(11582), np.float64(18553.0), np.float64(16319.0), np.float64(11178.0)] flow 1.000
#   req 10 path [np.int64(18553), np.float64(11582.0), np.float64(10045.0), np.int64(19555)] flow 55.000
#   req 10 path [np.int64(18553), np.float64(16319.0), np.float64(10045.0), np.int64(19555)] flow 2.000
#   req 11 path [np.int64(18553), np.int64(16319)] flow 47.000
#   req 12 path [np.int64(18553), np.int64(11582)] flow 15.000
#   req 13 path [np.int64(16319), np.float64(10045.0), np.int64(19555)] flow 1.000
#   req 14 path [np.int64(11582), np.float64(10380.0), np.int64(13505)] flow 26.000
#   req 15 path [np.int64(18553), np.float64(16319.0), np.int64(10045)] flow 1.000
#   req 16 path [np.int64(11582), np.int64(10380)] flow 105.000
#   req 18 path [np.int64(18553), np.float64(11582.0), np.float64(10380.0), np.int64(18655)] flow 1.000
#   req 19 path [np.int64(13505), np.float64(18655.0), np.int64(16319)] flow 62.000
#   req 20 path [np.int64(16319), np.float64(18553.0)] flow 51.000
#   req 21 path [np.int64(16319), np.int64(13505)] flow 63.000
#   req 22 path [np.int64(16319), np.float64(10045.0)] flow 51.000
#   req 23 path [np.int64(16319), np.float64(18553.0), np.int64(11582)] flow 19.000
#   req 24 path [np.int64(10045), np.float64(11582.0), np.float64(18553.0), np.int64(16319)] flow 1.000
#   req 25 path [np.int64(16319), np.float64(10045.0), np.float64(10380.0), np.int64(18655)] flow 3.000
#   req 25 path [np.int64(16319), np.float64(13505.0), np.int64(18655)] flow 27.000
#   req 17 path [np.int64(16319), np.float64(11178.0)] flow 57.000
#   req 1 path [np.int64(16319), np.float64(10380.0)] flow 90.000
#   req 3 path [np.int64(11178), np.float64(16319.0)] flow 71.000
